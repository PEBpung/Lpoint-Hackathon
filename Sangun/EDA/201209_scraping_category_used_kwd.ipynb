# %% [markdown]
#  * 라이브러리 호출

# %%
import numpy as np
import pandas as pd
import os
from collections import Counter
import datetime
from random import *
import re
import requests
from tqdm import tqdm


import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
from matplotlib.font_manager import fontManager
import plotly as py
import plotly.express as px
from pprint import pprint

import lxml
import bs4
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import seaborn as sns
import cufflinks as cf
# %matplotlib notebook
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
#  * 폰트

# %%
for font in fontManager.ttflist:
    if 'Mal' in font.name:
        print(font.name)
plt.rc('font', family='Malgun Gothic')
# Out:
# Lohit Malayalam
# Samyak Malayalam
# RaghuMalayalam

# %% [markdown]
#  * 데이터 파일 불러오기

# %%
# col_dtype = {'act_kwd':'str'}

# %%
merge_table = pd.read_csv('./merge_raw_1234.csv')
# merge_table = pd.read_csv('./merge_raw_1234.csv', dtype=col_dtype)
merge_table = merge_table.drop(['Unnamed: 0'], axis=1)
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (17,27) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
merge_table.head()
# Out:
#    clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0    72429        1        2            2      A03  20190919  22:09
# 1    72429        1        1            1      A03  20190919  22:09
# 2    72428        5        1            0      A01  20190918  06:37
# 3    72428        4        1            0      A01  20190914  23:42
# 4    72428        3        3            0      A01  20190914  21:50
#
#    hit_pss_tm  trans_id   sech_kwd  ...  de_dt  de_tm buy_am buy_ct  \
# 0      842130       NaN        NaN  ...    NaN    NaN    NaN    NaN
# 1      839064       NaN        NaN  ...    NaN    NaN    NaN    NaN
# 2       12568       NaN  라인에디션블라우스  ...    NaN    NaN    NaN    NaN
# 3      243555       NaN       펜디가방  ...    NaN    NaN    NaN    NaN
# 4      839771       NaN     페레가모가방  ...    NaN    NaN    NaN    NaN
#
#   clnt_gender  clnt_age clac_nm1  clac_nm2 clac_nm3  pd_c_2
# 0     unknown   unknown      NaN       NaN      NaN     NaN
# 1     unknown   unknown      NaN       NaN      NaN     NaN
# 2     unknown   unknown      NaN       NaN      NaN     NaN
# 3     unknown   unknown      NaN       NaN      NaN     NaN
# 4     unknown   unknown      NaN       NaN      NaN     NaN
#
# [5 rows x 27 columns]

# %% [markdown]
#  * 3번 이상 검색된 단어 불러오기

# %%
sech_kwd = merge_table['sech_kwd'].value_counts()
sech_kwd = sech_kwd[sech_kwd >= 3]
sech_kwd
# Out:
# 우유          8985
# 두부          5210
# 계란          5039
# 생수          4283
# 수박          2694
#             ...
# 감바스시즈닝         3
# 하기스 팬티         3
# 견과류오트리         3
# 생청국장           3
# 파크 니트 쇼트       3
# Name: sech_kwd, Length: 29900, dtype: int64

# %%
sech_kwd_list = list(sech_kwd.index)
sech_kwd_list
# Out:
# ['우유',
#  '두부',
#  '계란',
#  '생수',
#  '수박',
#  '라면',
#  '오이',
#  '콩나물',
#  '쌀',
#  '식빵',
#  '어묵',
#  '양파',
#  '과자',
#  '바나나',
#  '당근',
#  '상추',
#  '삼겹살',
#  '햇반',
#  '요구르트',
#  '복숭아',
#  '김',
#  '버섯',
#  '떡볶이',
#  '요플레',
#  '원피스',
#  '김치',
#  '대파',
#  '만두',
#  '닭',
#  '치즈',
#  '아이스크림',
#  '시금치',
#  '컵라면',
#  '햄',
#  '애호박',
#  '감자',
#  '양배추',
#  '삼다수',
#  '깻잎',
#  '신라면',
#  '토마토',
#  '짜파게티',
#  '빵',
#  '오징어',
#  '요거트',
#  '사과',
#  '카레',
#  '콜라',
#  '맛살',
#  '양상추',
#  '단무지',
#  '파프리카',
#  '부추',
#  '커피',
#  '쿠킹박스',
#  '서울우유',
#  '고구마',
#  '쌀10kg',
#  '무',
#  '돼지고기',
#  '소고기',
#  '사이다',
#  '휴지',
#  '포도',
#  '마늘',
#  '키친타올',
#  '호박',
#  '달걀',
#  '베이컨',
#  '비비고',
#  '파',
#  '두유',
#  '샐러드',
#  '핫도그',
#  '물티슈',
#  '소세지',
#  '참치',
#  '순두부',
#  '당면',
#  '마요네즈',
#  '고추장',
#  '계란30',
#  '새우',
#  '불고기',
#  '스팸',
#  '식용유',
#  '물',
#  '버터',
#  '진라면',
#  '닭가슴살',
#  '유부초밥',
#  '오뎅',
#  '바나나우유',
#  '배추',
#  '치약',
#  '식초',
#  '훈제오리',
#  '케찹',
#  '생리대',
#  '냉면',
#  '설탕',
#  '샴푸',
#  '쌀20kg',
#  '간장',
#  '숙주',
#  '화장지',
#  '비엔나',
#  '김밥',
#  '주방세제',
#  '자두',
#  '김밥김',
#  '돈까스',
#  '피자',
#  '쌈무',
#  '쌈장',
#  '카프리썬',
#  '귤',
#  '삼계탕',
#  '메추리알',
#  '한우',
#  '과일',
#  '옥수수',
#  '음료수',
#  '오리',
#  '탄산수',
#  '떡볶이떡',
#  '비빔면',
#  '참기름',
#  '생수2l',
#  '미역',
#  '브로콜리',
#  '방울토마토',
#  '빈폴레이디스',
#  '가지',
#  '청양고추',
#  '닭볶음탕',
#  '에고이스트',
#  '김밥세트',
#  '구찌가방',
#  '부침가루',
#  '시리얼',
#  '쌀20kg햅쌀',
#  '고추',
#  '찹쌀',
#  '칼국수',
#  '목살',
#  '락스',
#  '저지방우유',
#  '커피음료',
#  '멸치',
#  '생닭',
#  '김밥햄',
#  '고무장갑',
#  '된장',
#  '굴소스',
#  '씨리얼',
#  '결과 내 재 검색',
#  '쪽파',
#  '떡국떡',
#  '펩시',
#  '거봉',
#  '스파게티',
#  '나이키',
#  '생수500ml',
#  '카누',
#  '짜장',
#  '순대',
#  '고등어',
#  '우동',
#  '팽이버섯',
#  '아이시스',
#  '섬유유연제',
#  '부대찌개',
#  '골뱅이',
#  '에잇세컨즈여성',
#  '떡',
#  '새우깡',
#  '쫄면',
#  '비피더스',
#  '피자치즈',
#  '다우니',
#  '커피믹스',
#  '생크림',
#  '국거리',
#  '나이키운동화',
#  '볶음밥',
#  '배',
#  '코카콜라',
#  '써스데이아일랜드',
#  '보리차',
#  '맥주',
#  '국수',
#  '콩국물',
#  '맛술',
#  '전복',
#  '밀가루',
#  '아보카도',
#  '블라우스',
#  '갈비',
#  '베베드피노',
#  '올리고당',
#  '파인애플',
#  '라코스테 원피스',
#  '하남쭈꾸미',
#  '동그랑땡',
#  '스테이크',
#  '쭈꾸미',
#  '수세미',
#  '칫솔',
#  '종이컵',
#  '안성탕면',
#  '미쏘',
#  '올리브유',
#  '백산수',
#  '젤리',
#  '세제',
#  '대패삼겹살',
#  '소고기국거리',
#  '바디워시',
#  '꽃게',
#  '쥬스',
#  '진미채',
#  '초코파이',
#  '팥빙수',
#  '세탁세제',
#  '크리넥스',
#  '소면',
#  '포도씨유',
#  '너구리',
#  '무우',
#  '샤브샤브',
#  '키위',
#  '바지락',
#  '치킨',
#  '단호박',
#  '오렌지쥬스',
#  '매일우유',
#  '모짜렐라치즈',
#  '소시지',
#  '쓰레기봉투',
#  '카레용돼지고기',
#  '블랙라벨 스테이크',
#  '레몬',
#  '입생로랑',
#  '홈런볼',
#  '김자반',
#  '또띠아',
#  '소불고기',
#  '체리',
#  '비비고김치',
#  '떡갈비',
#  '커피우유',
#  'la갈비',
#  '각티슈',
#  '메론',
#  '샤틴원피스',
#  '연두부',
#  '엠엘비키즈',
#  '풀무원',
#  '여성샌들',
#  '지오다노',
#  '캔커피',
#  '고기',
#  '치킨너겟',
#  '롱원피스',
#  '블루베리',
#  '현미',
#  '콘푸라이트',
#  '다진마늘',
#  '선풍기',
#  '딸기잼',
#  '우엉',
#  '스파게티면',
#  '김밥재료',
#  '하기스',
#  '소금',
#  '돼지고기 앞다리',
#  '다시다',
#  '종가집김치',
#  '파스퇴르우유',
#  '에어프라이어',
#  '야채',
#  '불가리스',
#  '갈치',
#  '반찬',
#  '비요뜨',
#  '열무김치',
#  '불닭볶음면',
#  '목우촌',
#  '초코우유',
#  '아몬드',
#  '생선',
#  '다짐육',
#  '미림',
#  '쿨피스',
#  '청경채',
#  '아쿠아슈즈',
#  '비비고왕교자',
#  '쌈채소',
#  '숙주나물',
#  '온앤온',
#  '저스트마이사이즈',
#  '참외',
#  '삼다수2l',
#  '스낵면',
#  '후추',
#  '라코스테',
#  '감자튀김',
#  '크릴오일',
#  '파워에이드',
#  '에이치커넥트',
#  '쥐포',
#  '스파게티소스',
#  '멸균우유',
#  '연어',
#  '망고',
#  '돼지갈비',
#  '써스데이아일랜드원피스',
#  '맥심',
#  '물만두',
#  '톰보이',
#  '팬티라이너',
#  '열라면',
#  '크록스',
#  '차돌박이',
#  '새송이버섯',
#  '화장지 3겹',
#  '플레인요거트',
#  '비누',
#  '닭갈비',
#  '정관장',
#  '샤넬',
#  '누룽지',
#  '모닝빵',
#  '진간장',
#  '모이몰른',
#  '음료',
#  '지퍼백',
#  '순두부찌개양념',
#  '햅쌀',
#  '열무',
#  '고추가루',
#  '샤인머스켓',
#  '디스커버리',
#  '베이킹소다',
#  '비비고만두',
#  '쌈',
#  '삼계탕재료',
#  '비엔나소시지',
#  '설화수',
#  '타미힐피거여성',
#  '생수500ml삼다수',
#  '컵밥',
#  '제로콜라',
#  '앞다리',
#  '요쿠르트',
#  '호주산소고기',
#  '팝콘',
#  '오레오',
#  '야쿠르트',
#  '크래미',
#  '래핑차일드',
#  '여성원피스',
#  '트레비',
#  '쌀국수',
#  '티셔츠',
#  '초콜릿',
#  '고메',
#  '나이스클랍',
#  '나무하나',
#  '꿀',
#  '닭다리',
#  '새우젓',
#  '오뚜기',
#  '샤프란',
#  '델라스텔라',
#  '아디다스',
#  '프레시지',
#  '오뚜기밥',
#  '사세',
#  '파스퇴르',
#  '주스',
#  '사발면',
#  '에고이스트원피스',
#  '튀김가루',
#  '샌드위치햄',
#  '미나리',
#  '두루마리휴지',
#  '액티비아',
#  '몽쉘',
#  '래쉬가드',
#  '파스타',
#  '냉장고',
#  '육개장',
#  '껌',
#  '고사리',
#  '짜장라면',
#  '캐리어',
#  '기저귀',
#  '비타500',
#  '육개장사발면',
#  '짜요짜요',
#  '연유',
#  '청국장',
#  '꽈리고추',
#  '하겐다즈',
#  '쥬시쥬디',
#  '생강',
#  '죽',
#  '낙지',
#  '슬라이스햄',
#  '에어팟',
#  '표고버섯',
#  '깐마늘',
#  '사골곰탕',
#  '소스',
#  '오렌지',
#  '에잇세컨즈',
#  '연두',
#  '호떡',
#  '맥심모카골드',
#  '칸타타',
#  '구찌',
#  '반에이크',
#  '등심',
#  '빼빼로',
#  '레쓰비',
#  '백팩',
#  '요리하다',
#  '소주',
#  '등갈비',
#  '퍼실',
#  '꼬깔콘',
#  '식혜',
#  '핏플랍',
#  '탄산음료',
#  '쌀과자',
#  '조셉앤스테이시',
#  '막창',
#  '둥지냉면',
#  '포카칩',
#  '풀무원 만두',
#  '진라면 순한맛',
#  '파채',
#  '하늘보리',
#  '프링글스',
#  '곤약',
#  '울샴푸',
#  '더아이잗원피스',
#  '다담',
#  '마라',
#  '종이호일',
#  '마라탕',
#  '총각김치',
#  '아디다스운동화',
#  '그래놀라',
#  '냉면육수',
#  '유산균',
#  'La갈비',
#  '스프',
#  '오예스',
#  '느타리버섯',
#  '슬리퍼',
#  '운동화',
#  '베지밀',
#  '오뚜기밥즉석밥',
#  '휴지30롤 3겹',
#  'lbl',
#  '생수 2l',
#  '캔맥주',
#  '트렌치코트',
#  '올리브데올리브',
#  '국간장',
#  '맨투맨',
#  '밤',
#  '매그제이',
#  '다시마',
#  '도토리묵',
#  '크림치즈',
#  '과탄산소다',
#  '에어컨',
#  '파파야',
#  '견과류',
#  '찜갈비',
#  '닭발',
#  '피죤',
#  '유부',
#  '토종닭',
#  '스타벅스',
#  '토스트식빵',
#  '핫케익가루',
#  '머스타드',
#  '델리우드',
#  '스커트',
#  '대패',
#  '김치만두',
#  '달팡',
#  '랩',
#  '자몽',
#  '구운계란',
#  '호주산',
#  '블루독베이비',
#  '탕수육',
#  '약과',
#  '수제비',
#  '돼지고기다짐육',
#  '플라스틱아일랜드',
#  '빠아앙',
#  '무료배송',
#  '고추참치',
#  '에코백',
#  '육포',
#  '아몬드후레이크',
#  '코코볼',
#  '오뚜기피자',
#  '앞다리살',
#  '불고기양념',
#  '순대국',
#  '치즈스틱',
#  '로브가디건',
#  '칠성사이다',
#  '김말이',
#  '스파게티면 소스',
#  '탑텐',
#  '무화과',
#  '들기름',
#  '귀리',
#  '이온음료',
#  '연근',
#  '토리버치가방',
#  '김가루',
#  '드레싱',
#  '에블린',
#  '사탕',
#  '염색약',
#  '미숫가루',
#  '여성블라우스',
#  '비트',
#  '카스타드',
#  '돈까스소스',
#  '도라지',
#  '용가리',
#  'LA갈비',
#  '르샵',
#  '스위트콘',
#  '에이치커넥트여성',
#  '피망',
#  '건전지',
#  '에스티로더',
#  '옥수수수염차',
#  '소화가잘되는우유',
#  '샌들',
#  '카레가루',
#  '환타',
#  '초코송이',
#  '다우니 섬유유연제',
#  '신라면 건면',
#  '나이스클랍코트',
#  '뽀로로',
#  '헤지스레이디스',
#  '맛소금',
#  '프라다가방',
#  '도시락김',
#  '돈가스',
#  '와사비',
#  '미역국',
#  '생크림요거트',
#  '나물',
#  '된장찌개',
#  '채소',
#  '아욱',
#  '오리훈제',
#  '갈비양념',
#  '오징어채',
#  '계란15',
#  '양파링',
#  '린스',
#  '천도복숭아',
#  '미미네떡볶이',
#  '알배기배추',
#  '오리고기',
#  '유한락스',
#  '골드키위',
#  '크리넥스 화장지 3겹',
#  '사골',
#  '대추',
#  '햇반210g',
#  '장조림',
#  '양조식초',
#  '청포도',
#  '헤지스',
#  '꿀호떡',
#  '크로스백',
#  '여성구두',
#  '잡곡',
#  '유정란',
#  '트리트먼트',
#  '잡채용돼지고기',
#  '김밥단무지',
#  '떠먹는요구르트',
#  '너겟',
#  '콘칩',
#  '삼양라면',
#  '평창수',
#  '잼',
#  '팥',
#  '왕뚜껑',
#  '크린랩',
#  '포카리스웨트',
#  '샤브샤브용 소고기',
#  '메밀소바',
#  '세수비누',
#  '후라이팬',
#  '샐러드드레싱',
#  '나뚜루',
#  '린넨원피스',
#  '액체세제',
#  '얼음',
#  '에이스',
#  '바람막이',
#  '튀김우동',
#  '호두',
#  '여성가방',
#  '떡국',
#  '노스페이스키즈',
#  '라코스테신발',
#  '갈비탕',
#  '가을원피스',
#  '영계',
#  '옥수수캔',
#  '면도기',
#  '소갈비양념',
#  '나스',
#  '슬립온',
#  '초고추장',
#  '래쉬가드여성',
#  '노트북',
#  '물엿',
#  '와이드앵글',
#  '부탄가스',
#  '얇은피꽉찬속김치만두',
#  '핸드워시',
#  '빈폴키즈',
#  '무쌈',
#  '아메리카노',
#  '맛동산',
#  '알배추',
#  '고래밥',
#  '생수300',
#  '종량제봉투',
#  '마시는요구르트',
#  '국산콩두부',
#  '쨈',
#  '건면',
#  '우삼겹',
#  '올리브오일',
#  '컵반',
#  '칼국수면',
#  '여성자켓',
#  '노트10',
#  '동태전',
#  '콘푸로스트',
#  '생수500',
#  '시금치한단',
#  '비닐팩',
#  '맥',
#  '조기',
#  '리챔',
#  '카놀라유',
#  '가디건',
#  '키플링알바',
#  '모코블링',
#  '초밥',
#  '달걀30',
#  '신일에어서큘레이터',
#  '딸기우유',
#  '키엘',
#  '도시락',
#  '동태',
#  '다논',
#  '샐러드야채',
#  '마라탕면',
#  '잡채',
#  '디올',
#  '코치가방',
#  '라우렐',
#  '오이고추',
#  '티슈',
#  '카드지갑',
#  '목우촌햄',
#  '다향 훈제오리',
#  '양송이',
#  '밀키스',
#  '게토레이',
#  '퐁퐁',
#  '춘장',
#  '떡볶이떡 쌀',
#  '종가집',
#  '짜장면',
#  '하남쭈꾸미500g',
#  '아이스티',
#  '카레여왕',
#  '스트링치즈',
#  'abfz여름원피스',
#  '헤라',
#  '아디다스키즈',
#  '내셔널지오그래픽',
#  '케네스레이디',
#  '곤약젤리',
#  '콘프레이크',
#  '크린백',
#  '이오',
#  '플라스틱아일랜드원피스',
#  '나인',
#  '풀무원두부',
#  '풀무원계란',
#  '컨버스',
#  '안심',
#  '여성수영복',
#  '다이슨에어랩',
#  '삼다수6입',
#  '에어팟2',
#  '파타고니아',
#  '케일',
#  '휠라키즈',
#  '뒷다리',
#  '황태채',
#  '닥스키즈',
#  '오이지',
#  '컵누들',
#  '빙그레 바나나우유',
#  '빵가루',
#  '설레임',
#  '흰우유',
#  '고향만두',
#  '비닐장갑',
#  '하리보',
#  '팔도비빔면',
#  '감자칩',
#  '감바스',
#  '짜왕',
#  '롱스커트',
#  '토모톰스',
#  '한우등심',
#  '후드집업',
#  '자켓',
#  '티렌',
#  '속옷',
#  '자일리톨껌',
#  '코트',
#  '홍초',
#  '잘모이',
#  '로엠',
#  '향수',
#  '돼지목살',
#  '첫구매',
#  '양조간장',
#  '빙그레',
#  '양산',
#  '오렌지주스',
#  '주방세제리필',
#  '신라면 컵라면',
#  '행주',
#  '잇미샤',
#  '우유식빵',
#  '랩원피스',
#  '백숙',
#  '메트로시티주얼리',
#  '린넨자켓',
#  '베네피트',
#  '납작당면',
#  '황도',
#  '오레오오즈',
#  '깨소금',
#  '빈츠',
#  '묵',
#  '즉석밥',
#  '제이제이지고트',
#  '톰앤래빗',
#  '밸리걸',
#  '오징어튀김',
#  '여성운동화',
#  '홍고추',
#  '삼계탕 생닭',
#  '아기치즈',
#  '위생백',
#  '빈폴레이디스원피스',
#  '라이스페이퍼',
#  '멸치액젓',
#  '입생로랑립스틱',
#  '흙대파',
#  '참깨라면',
#  '목심',
#  '부채살',
#  '아몬드브리즈',
#  '뽀로로음료수',
#  '오징어땅콩',
#  '썬업',
#  '스톤아일랜드',
#  '요플레플레인',
#  '칠리소스',
#  '제습제',
#  '물냉면',
#  '월남쌈',
#  '국산콩나물',
#  '리스트',
#  '닭봉',
#  'MLB키즈',
#  '곱창',
#  '섬유유연제리필',
#  '브로컬리',
#  '농부의미소 20kg/포',
#  '고춧가루',
#  '다이슨',
#  '페브리즈',
#  '하림',
#  '바비브라운',
#  '지고트원피스',
#  '얼갈이',
#  '농심',
#  '코카콜라제로',
#  '테크',
#  '록시땅',
#  '고당도수박',
#  '국',
#  '체다치즈',
#  '미니멈',
#  '미역줄기',
#  '초당옥수수',
#  '조개',
#  '꽁치',
#  '쌀20',
#  '물티슈100매',
#  '액젓',
#  '파스타면',
#  '피클',
#  '아레나 여성수영복',
#  '타미힐피거남성',
#  '가방',
#  '뉴발란스키즈',
#  '코코팜',
#  '스프라이트',
#  '버팔로윙',
#  '다이나핏',
#  '락앤락',
#  '삼겹',
#  '특란',
#  '생리대 대형',
#  '쌀 10kg',
#  '원피스 여성원피스',
#  '귀걸이',
#  '스니커즈',
#  '굴비',
#  '여성 블라우스',
#  '믹서기',
#  '우동사리',
#  '쑥갓',
#  '맥스봉',
#  '파스타소스',
#  '양말',
#  '세탁기',
#  '여성티셔츠',
#  '노스페이스',
#  '골프웨어',
#  '애플수박',
#  '여성골프웨어',
#  '블루독',
#  '육수',
#  '황태',
#  '아이시스8.0 2l',
#  '소갈비',
#  '라면사리',
#  '나이키키즈',
#  '여성시계',
#  '목걸이',
#  'LAP 원피스',
#  '선글라스',
#  '나또',
#  '게맛살',
#  '코치',
#  '토레타',
#  '고메핫도그',
#  '메트로시티가방',
#  '청바지',
#  '양배추 1/2',
#  '참치캔',
#  '칸쵸',
#  '김치냉장고',
#  '데싱디바',
#  '조던키즈',
#  '보쌈',
#  '쿠키',
#  '랑콤',
#  '메밀',
#  '팔찌',
#  '갈비찜',
#  '풀무원 두부',
#  '삼치',
#  '콘트라베이스',
#  '고시히카리',
#  '흑미',
#  '초코',
#  '올리브',
#  '밍크뮤',
#  '마이클코어스가방',
#  '안다르',
#  '국물떡볶이',
#  '돼지불고기',
#  '찌개용돼지고기',
#  '남성반바지',
#  '땅콩',
#  '상추쌈채소',
#  '상하목장',
#  'mixxo',
#  '판계란30',
#  '녹두',
#  '굵은소금',
#  '라인원피스',
#  '쓰레기봉투10',
#  '샌드위치',
#  '볶음용멸치',
#  '날치알',
#  '나쵸',
#  '블랙야크키즈',
#  '남양우유',
#  '여성슬립온',
#  '대추방울토마토',
#  '치킨스톡',
#  '양송이버섯',
#  '타미진',
#  '미바왕쿠션',
#  '생생우동',
#  '빈폴',
#  '샐러리',
#  '헤지스키즈',
#  '뉴슈가',
#  '입생로랑틴트',
#  '마늘쫑',
#  '좋은느낌',
#  '여성반바지',
#  '석류',
#  '쿠킹박스1 1',
#  '군만두',
#  '플레인',
#  '슈콤마보니',
#  '타미힐피거여성원피스',
#  '쇼퍼백',
#  '카누미니',
#  '죠리퐁',
#  '맛밤',
#  '스낵',
#  '여성 샌들',
#  '데상트',
#  '빈폴아웃도어',
#  '치토스',
#  '냉동식품',
#  '햄버거',
#  '쿠쿠압력밥솥6인용',
#  '업타운홀릭',
#  '라떼',
#  '빨래비누',
#  '오조크',
#  '새송이',
#  '레노마키즈 남아',
#  '동태포',
#  '네셔널지오그래픽',
#  '콜드',
#  '탄산수 트레비',
#  '욕실화',
#  '바디로션',
#  '미친데이',
#  '닭안심',
#  '오버나이트',
#  '박카스',
#  '미니돈까스',
#  '햇사레복숭아',
#  '제습기',
#  '안주야',
#  '호주',
#  '가그린',
#  '바나나킥',
#  '뼈해장국',
#  '타미힐피거',
#  '크록스 남성',
#  '프라다',
#  '저지방',
#  '수영복',
#  '위생팩',
#  '사세 버팔로윙',
#  '맥 립스틱',
#  '토마토소스',
#  '낫또',
#  '탄산',
#  '칙촉',
#  '콩물',
#  '여성 반바지',
#  '밑반찬',
#  '수건',
#  '꿀꽈배기',
#  '윙',
#  ...]

# %%
len(sech_kwd_list)
# Out:
# 29900

# %% [markdown]
#  * 3번 이상 검색된 단어만 따로 열 만들기

# %%
merge_table['act_kwd_over3'] = merge_table['act_kwd'][merge_table['act_kwd'].isin(sech_kwd_list)]
merge_table['act_kwd_over3']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3            펜디가방
# 4          페레가모가방
#             ...
# 3196357       NaN
# 3196358       NaN
# 3196359     과일바구니
# 3196360       NaN
# 3196361    과일선물세트
# Name: act_kwd_over3, Length: 3196362, dtype: object

# %%
merge_table['act_kwd_over3'].nunique()
# Out:
# 29900

# %% [markdown]
# * 키워드 리스트 불러오기

# %%
act_kwd_over3 = list(merge_table['act_kwd_over3'].unique())
act_kwd_over3.remove(np.nan)
act_kwd_over3
# Out:
# ['펜디가방',
#  '페레가모가방',
#  '루이비통',
#  '구찌',
#  '속옷세트',
#  '핫도그',
#  '원피스',
#  '아이패스파워',
#  '계란',
#  'enqn',
#  '멜빵바지',
#  '보쌈용',
#  '삼겹',
#  '보쌈',
#  '수박',
#  '앞다리',
#  '찌개용',
#  '비비고포기김치',
#  '미숫가루',
#  '햇반210g',
#  '계란30',
#  '종근당 락토핏',
#  '비엔나',
#  '팸퍼스',
#  '호두',
#  '닭갈비',
#  '피쇼',
#  '펩시',
#  '골뱅이',
#  '쌀',
#  '맥스클리닉',
#  '빠질라카노',
#  '구찌 지갑',
#  '남자구찌지갑',
#  '프라다 지갑',
#  '빈폴지갑',
#  '프라다지갑',
#  '남자지갑',
#  '몽블랑지갑',
#  '지갑',
#  '베이퍼맥스',
#  '떡',
#  '비누',
#  '천연비누',
#  '밍크코트',
#  '가죽잠바',
#  '고추장',
#  '최유라쇼',
#  '닥스양산',
#  '양산',
#  '양산 uv차단',
#  '키친타올',
#  '서큘레이터',
#  '파세코',
#  '르젠',
#  '리리코스',
#  '파세코 써큘레이터',
#  '고시히카리',
#  '잘모이',
#  '파타고니아후리스',
#  '물걸레청소포',
#  '써스데이아일랜드원피스',
#  '만두피',
#  '생만두피',
#  '냉동만두피',
#  '왕만두피',
#  '닭발',
#  '라인댄스화',
#  '발톱네일아트',
#  '발톱레일',
#  '상품권',
#  '기프트카드',
#  '김',
#  '양배추',
#  '오일',
#  '보테가베네타남자지갑',
#  '온앤온',
#  '코렐',
#  '오덴세',
#  '루카스나인라떼',
#  '바지걸이',
#  '스타벅스',
#  '▣셔츠',
#  '흄',
#  '복합기',
#  '로퍼',
#  '소보제화',
#  '고데기',
#  '봉고데기',
#  '뽕고데기',
#  '손목지갑',
#  '손목시계',
#  '집게핀',
#  '립 마에스트로',
#  '헤지스키즈',
#  '헤지스레이디스 원피스',
#  '셔츠원피스',
#  '여성 레이어드 티셔츠',
#  '여성 롱 티셔츠',
#  '꼬망스',
#  '빈 원피스',
#  '매니큐어',
#  '샤넬 르베르니',
#  '백산수',
#  '흑설탕',
#  '조거팬츠 여성',
#  '선풍기커버',
#  '흙침대',
#  '프레쉬 립밤',
#  '데싱디바',
#  '입생로랑',
#  '코코 플래쉬',
#  '유기농설탕',
#  '각설탕',
#  '할리스',
#  '라떼',
#  '헤지스레이디스 팬츠',
#  '섀도우팔레트',
#  '햇사과',
#  '청송사과',
#  '헤지스레이디스 가디건',
#  '나스 립스틱',
#  '타미힐피거 스커트',
#  '차량용핸드폰거치대',
#  '디올 립스틱',
#  '헤지스 청스커트',
#  '마약베개',
#  '바디럽',
#  '빈 여아',
#  '빈',
#  '타미힐피거칠드런',
#  '비비안 노와이어 브라',
#  '노와이어브라',
#  '노스페이스 카라티',
#  '낙지젓갈',
#  '포도',
#  '정관장에브리타임 밸런스',
#  '라코스테 스커트',
#  '데님 스커트',
#  '에브리타임',
#  '밴딩스커트',
#  '무광집게핀',
#  '헤어핀',
#  '차퍼',
#  '스타벅스 에스프레소',
#  '그릴팬',
#  '셀렉스',
#  '여아 수영복',
#  '베네피트 아이브로우',
#  '요리책',
#  '핏플랍',
#  '멜리사젤리슈즈',
#  '바비브라운 아이브로우',
#  '아이브로우',
#  '더반찬',
#  '밑반찬',
#  '세차용품',
#  '헤어밴드',
#  '치간칫솔',
#  '홍삼정 에브리타임',
#  '스파클라',
#  '핸들커버',
#  '키홀더',
#  '폴라레티',
#  '고양이사료',
#  '워터젤리',
#  '해바라기',
#  '라코스테 가방',
#  '전자피아노',
#  '빈 블라우스',
#  '칫솔살균기',
#  '헤지스키즈 티셔츠',
#  '아이스바',
#  '국자',
#  '손목보호대',
#  '해바라기씨',
#  '디올립스틱',
#  '록시땅 버베나',
#  '입생로랑워터틴트',
#  '워터틴트',
#  '에스티로더 립스틱',
#  '에스티로더 크림',
#  '에스티로더',
#  '슈에무라립스틱',
#  '입생로랑립스틱',
#  '조말론블랙베리앤베이',
#  '샤넬 가브리엘',
#  '샤넬 향수',
#  '바비브라운 브로우',
#  '유니클로',
#  '필립스 드라이기',
#  '에스티로더 마스카라',
#  '쿠론 크로스백',
#  '얼그레이',
#  '홍차',
#  '헤지스레이디스 바지',
#  '유칼립투스',
#  '꼬막장',
#  '록시땅 샴푸',
#  '구명조끼',
#  '핸드폰지갑',
#  '우바블라우스',
#  '간장',
#  '레노마남성크로스백',
#  '바쵸바치',
#  '헤지스남성티셔츠',
#  '나무하나',
#  '운동화',
#  '태그호이어',
#  '이노베돈',
#  '롯데면세점',
#  '남자 파우치',
#  '질레트',
#  '남성 클러치백',
#  '리클라이너 1인용',
#  '자전거',
#  '버버리 남성',
#  '저지방우유',
#  '루이비통 백',
#  '남성 래쉬가드',
#  '아레나 남성 래쉬가드',
#  '여성 집업 래쉬가드',
#  '래쉬가드',
#  '아레나 래쉬가드',
#  '노스페이스키즈',
#  '루이비똥지갑',
#  '배럴키즈 래시가드',
#  '배럴키즈',
#  'jpx919포지드',
#  '계란곤약',
#  '스포츠브라세트',
#  '코데즈컴바인여성팬티',
#  '로얄테일즈',
#  '버섯',
#  '갈비양념',
#  '불고기',
#  '카레',
#  '하이라이스',
#  '카레용돼지고기',
#  '감자',
#  '씨그램',
#  '퍼실',
#  '울샴푸',
#  '식초',
#  '종가집김치',
#  '깻잎',
#  '양파',
#  '불고기양념',
#  '마늘',
#  '뉴슈가',
#  '비비고왕교자',
#  '떡국떡',
#  '오뚜기 사골',
#  '옥수수',
#  '떡국',
#  '다담',
#  '손세정',
#  '육개장 사발면',
#  '트레비',
#  '애터미',
#  '마르니트렁크백 미니',
#  '지고트',
#  '데코',
#  '지고트자켓',
#  '비씨비지',
#  '미니멈자켓',
#  '지고트 자켓',
#  '더아이잗',
#  '데코자켓',
#  '다이슨드라이기',
#  '비씨비지블라우스',
#  '미니멈',
#  '비비안브라팬티세트',
#  '비너스브라팬티세트',
#  '비너스브라',
#  '캠퍼여성신발',
#  '캠퍼여성샌들',
#  '아이잗바바블라우스',
#  '지고트블라우스',
#  '비씨비지니트',
#  '키이스',
#  '사만사타바사가방',
#  '아이잗바바',
#  '샴푸',
#  '랑콤립스틱',
#  '미니멈블라우스',
#  '오조크티셔츠',
#  '오조크블라우스',
#  '여성샌들',
#  '옥수수수염차',
#  '밍크뮤 바디슈트',
#  's831s32',
#  '베스띠벨리',
#  '베스티벨리',
#  '블라우스',
#  '쿠론',
#  '러브캣',
#  '다이슨고데기',
#  '다이슨',
#  '에버홈',
#  '믹서기',
#  '쿠션팩트',
#  '와이드팬츠',
#  '쿠션',
#  '빌리프',
#  '베네피트',
#  '눈썹마스카라',
#  '남자속옷',
#  '남자반팔티',
#  '에센스',
#  '모자',
#  'CK남자속옷',
#  '커피 선물세트',
#  '커피',
#  '바디로션',
#  '베스트벨리',
#  '레노마레이디',
#  '롱스커트',
#  '로라메르시에',
#  '립스틱',
#  '꼼빠니아',
#  '잇미샤',
#  '슈콤마보니',
#  '슈콤마보니샌들',
#  '샌들',
#  '남성티셔츠',
#  '티셔츠',
#  '프라이머',
#  '캔버스백',
#  '입생로랑틴트',
#  '입생로랑 cc',
#  '입생로랑 cc크림',
#  '블러셔',
#  '버버리',
#  '명품백',
#  '빅백',
#  '프라이팬',
#  '77원피스',
#  '쉬폰원피스',
#  '요플레',
#  '샤인머스켓',
#  '쌀20kg햅쌀',
#  '사골',
#  '사골곰탕',
#  '여성티셔츠',
#  '시금치',
#  '당근',
#  '파프리카',
#  '백도',
#  '검은콩 참깨두유',
#  '코리아나 앰플엔',
#  '벽걸이에어컨',
#  '에어컨',
#  '이동식에어컨',
#  '일월이동식에어컨',
#  '만두',
#  '물',
#  '피죤',
#  '콜드',
#  '휴지',
#  '도시락',
#  '그레놀라',
#  '초코에몽',
#  '오렌지주스',
#  '욕실청소',
#  '유한락스',
#  '초코우유',
#  '음료',
#  '썬칩',
#  '그래놀라',
#  '우유',
#  '배선물세트',
#  '스탠드조명',
#  'TRYSIL',
#  'FC6813/01',
#  '협탁',
#  '한샘식탁',
#  '일리윤',
#  '세라마이드',
#  '록시땅',
#  '아르마니 립마그넷',
#  '섹스어필',
#  '어딕션',
#  '린넨원피스',
#  '발렌티노클러치',
#  '발렌티노 락스터드',
#  '초콜릿',
#  '과자',
#  '두유',
#  '새콤달콤',
#  '젤리',
#  '블루독베이비 상하복',
#  '오복간장',
#  '상품평',
#  'a4용지',
#  '티스푼',
#  '종량제봉투10',
#  '크린백',
#  '종이호일',
#  '크린랩',
#  '지퍼백',
#  '랩',
#  '호가든',
#  '코카콜라 제로',
#  '물티슈',
#  '쌈장',
#  '이엔씨 원피스',
#  '올리브데올리브 원피스',
#  '생수500',
#  '신동진쌀20kg햅쌀',
#  '아이스크림',
#  '닭가슴살 볶음밥',
#  '새우볶음밥',
#  '무우',
#  '닭가슴살',
#  '베이킹소다',
#  '빙그레 바나나우유',
#  '유부초밥',
#  '요플레플레인',
#  '순쌀떡볶이',
#  '국물떡볶이',
#  '치즈',
#  '미장센에센스',
#  '미장센 세럼',
#  '하우스바몬드카레',
#  '빠다코코넛',
#  '케이퍼',
#  '요거트',
#  '라이너',
#  '풀무원 국물떡볶이',
#  '순살떡볶이',
#  '볶음밥',
#  '닭안심살',
#  '쌈채소',
#  '그릭요거트',
#  '떡볶이',
#  '요거트 플레인',
#  '요플레플레인요거트',
#  '플레인요거트',
#  '돼지고기 앞다리',
#  '샌드위치',
#  '하남쭈꾸미500g',
#  '나이키',
#  '테팔후라이팬',
#  '테팔컴포트 그립후라이팬',
#  '삼다수',
#  '샤틴 레이스블라우스',
#  '맛김치',
#  '메소드 주방세제',
#  '메소드주방세제',
#  '이불커버',
#  '크릴오일',
#  '남자 흰색바지',
#  '닥스 셔츠',
#  '닥스 남방',
#  '고메치킨',
#  '다리미판',
#  '갤럭시노트10 kt',
#  '갤럭시노트10 sk',
#  '갤럭시노트10',
#  '슬립',
#  '지오다노',
#  '자켓',
#  '고구마',
#  '달걀',
#  '애호박',
#  '치킨너겟',
#  '소세지',
#  '생수',
#  '체다슬라이스치즈',
#  '대파',
#  '닭',
#  '짜장',
#  '쿠킹박스',
#  '햄',
#  '청양고추',
#  '씨리얼',
#  '어린이음료',
#  '요리하다 냉동',
#  '파',
#  '단무지',
#  '초코송이',
#  '오징어실채',
#  '맥콜',
#  '훈제오리',
#  '쌀10kg',
#  '햅쌀',
#  '키친타월',
#  '요구르트',
#  '소금',
#  '굵은소금',
#  '햅쌀10kg',
#  '장어',
#  '팬티라이너',
#  '생리대',
#  '스파게티',
#  '스파게티면',
#  '오리슬라이스',
#  '오리',
#  '클리오',
#  '칫솔',
#  '스팸',
#  '주방세제',
#  '남성 셔츠',
#  '니트가디건',
#  '클렌징오일',
#  '설화수',
#  '파워에이드',
#  '자몽',
#  '여자수영복',
#  '지프반팔티',
#  '반팔티',
#  '폴로랄프로렌',
#  '설탕',
#  '매일우유',
#  '가는소금',
#  '꿀',
#  '두부',
#  '에스티로더더블웨어파운데이션',
#  '락앤락비스프리',
#  '남자 명품 클러치',
#  '카놀라유',
#  '식용류',
#  '콩기름 식용유',
#  '포도씨유',
#  '사과',
#  '바나나',
#  '첫구매제주삼다수2l',
#  '삼다수2l',
#  '배',
#  '한우안심',
#  '한우 안심',
#  '삼다수 2l',
#  'c74j156',
#  '무드등',
#  'c81j156',
#  'c81k131',
#  'c73j163',
#  'c74h158',
#  '벨라디터치',
#  'c73j263',
#  'c74h152',
#  '엠씨니트',
#  'c82t014',
#  'c73b164',
#  '다이슨에어랩',
#  '돼지목살',
#  '호주산소고기',
#  '원두커피',
#  '앨리스 핸드폰 케이스',
#  '홍로',
#  '라면',
#  '신라면',
#  '섬유유연제',
#  '샤프란',
#  '김치',
#  '용가리 치킨너겟',
#  '주방세제퐁퐁',
#  '락스',
#  '거봉',
#  '크린랩 위생장갑',
#  '위생봉투',
#  '지퍼팩',
#  '컵라면',
#  '주스',
#  '탄산음료',
#  '음료수',
#  '옛날과자',
#  '과일',
#  '리챔',
#  '멸치',
#  '광천김',
#  '생리대오버나이트',
#  '투게더아이스크림',
#  '케이준감자',
#  '모기약',
#  '엘지프라엘',
#  '남아츄리닝',
#  '레노마남성신발',
#  '남성티',
#  '페레가모벨트',
#  '여성벨트',
#  '골프웨어',
#  '버킷백',
#  '여성가방',
#  '샤넬립스틱',
#  '도로시',
#  '귀걸이',
#  '디올어딕트립글로우',
#  '샤넬향수',
#  '디올 향수',
#  '남성가디건',
#  '남성신발',
#  '타미힐피거운동화',
#  '타미힐피거여성',
#  '백팩',
#  '여성지갑',
#  '남성티셔츠 긴팔',
#  '업타운홀릭',
#  '구찌반지갑',
#  '원더브라',
#  '지방시',
#  '가방',
#  '정관장',
#  '여성구두',
#  '나이키힙색',
#  '침구',
#  '스티브매든',
#  '쪼리샌들',
#  '여성뮬',
#  '입생로랑쿠션',
#  '파인드카푸어핑고백',
#  '마이클코어스가방',
#  '탠디 남성화',
#  '영화관람권',
#  '마이클코어스',
#  '자라',
#  '점프슈트',
#  '바겐스탁',
#  '알도샌들',
#  '닥터마틴',
#  '뮬슬리퍼',
#  '뮬',
#  '휠라뮬',
#  '케즈 뮬',
#  '케즈 스니커즈',
#  '뮬스니커즈',
#  '스니커즈뮬',
#  '케즈',
#  '점프슈트 여성',
#  '파인드카푸어',
#  '원더브라 브라팬티세트',
#  '엘로엘 선쿠션',
#  '슬리퍼',
#  '아이크림',
#  '남성수제화',
#  '헉슬리',
#  '닥터자르트',
#  '차앤박',
#  '닥터자르트 선크림',
#  '선크림',
#  '비오템',
#  '윤조에센스',
#  '에코백',
#  '이니스프리',
#  '프라다힙색',
#  '프라다크로스백',
#  '마크제이콥스가방',
#  '힙색',
#  '알도여성샌들',
#  '쿠론가방',
#  '롯데 모바일상품권',
#  '덱케',
#  '덱케가방',
#  '조셉앤스테이시니트백',
#  '훌라가방',
#  '여성크로스가방',
#  '조셉앤스테이시',
#  '잡곡',
#  '멸균우유',
#  '소고기',
#  '초당',
#  '메트로시티 체인백',
#  '르꼬끄',
#  '메트로시티가방',
#  '메트로시티',
#  '리복 운동화',
#  '프로스펙스 운동화',
#  '남성 운동화',
#  '베스트슬립M5',
#  '에몬스',
#  '에몬스침대',
#  '신발주머니',
#  'kmw18587',
#  '자',
#  '샤프심',
#  '솔로몬샵',
#  '지우개',
#  '식탁의자',
#  '14K 귀걸이',
#  '14K 팔찌',
#  '화이트폭스',
#  'k2',
#  '코오롱스포츠',
#  '블루투스스피커',
#  '저상형침대',
#  '침대프레임',
#  '메리골드',
#  '메리골드차',
#  '마리골드',
#  '쾌변두유',
#  '매일두유',
#  '뉴트라라이프',
#  '눈영양제',
#  '구워먹는치즈',
#  '스팸 마일드',
#  '엘지 x4',
#  '미센스',
#  '퀵슬립',
#  '매트리스',
#  '맥심 모카골드',
#  '맥심',
#  '매일유업',
#  '콜라',
#  '침대',
#  '맛있는라면',
#  'K2',
#  '쿨매트',
#  '에어퀸생리대',
#  '올즙 석류즙',
#  '석류즙',
#  '고세',
#  '푸딩',
#  '린넨원피스 여성',
#  '려',
#  '컴포트랩',
#  '면 원피스',
#  '롱원피스',
#  '약통',
#  '도브바디워시',
#  '바디워시',
#  '3단우산',
#  '빅그린',
#  '메리바움',
#  '델라스텔라가방',
#  '키높이깔창',
#  '깔창',
#  '배드민턴라켓',
#  '제이핑크',
#  '여성 벨트',
#  '더아이잗 자켓',
#  '롯데닷컴',
#  '현미',
#  '무',
#  '어묵',
#  '팽이버섯',
#  '닭고기',
#  '잡채고기',
#  '오이',
#  '호박',
#  '참치',
#  '생크림',
#  '갓김치',
#  '열무김치',
#  '숙주',
#  '비비고 열무김치',
#  '비비고',
#  '청귤',
#  '고구마줄기',
#  '미림',
#  '맛술',
#  '토마토',
#  '귀리',
#  '버터',
#  '무염버터',
#  '콩나물',
#  '쓰레기봉투',
#  '리얼그래놀라',
#  '와사비',
#  '목살',
#  '헤드앤숄더애플프레쉬샴푸550ml',
#  '헤드앤숄더',
#  '고추',
#  '오이 고추',
#  '오이고추',
#  '상추',
#  '나트라케어',
#  '메밀국수',
#  '삼계탕재료',
#  '삼계탕',
#  '총각김치',
#  '풀무원핫도그',
#  '풀무원',
#  '가지',
#  '배추',
#  '새송이버섯',
#  '국거리',
#  '과탄산소다 세탁세제',
#  '무항생제 유정란',
#  '홍이장군',
#  '타미힐피거',
#  '타미힐피거남성',
#  '리바트 화장대',
#  '일반세탁기',
#  'zb3323bo',
#  '프리메라',
#  '아레나 여성수영복',
#  '샘플',
#  '여성자켓',
#  '여성정장자켓',
#  '나이키운동화',
#  '세인트마리',
#  '오드자켓',
#  '오드',
#  '오드 블라우스',
#  '오드원피스',
#  '마사지',
#  '복숭아',
#  '닥스남성점퍼',
#  '오드 스커트',
#  '크록스 여성',
#  '크룩스',
#  '헤라',
#  '안나수이',
#  '쿤달샴푸',
#  '동원죽',
#  '주시주디',
#  '남성반팔',
#  '노트10',
#  '갤럭시워치',
#  '나이키 탄준 샌들',
#  '숏자켓',
#  '미스디올',
#  '슈에무라',
#  '맥',
#  '톰브라운',
#  '온앤온블라우스',
#  '여성체크자켓',
#  '체크자켓',
#  '바비브라운',
#  '바비브라운 럭스',
#  '씨씨콜렉트',
#  '발리가방',
#  '발리',
#  '민소매원피스',
#  '이경제황제천용단',
#  '이경제',
#  '공진단',
#  '서스펜더 원피스',
#  'S10 5G 케이스',
#  '휴대폰케이스',
#  '아딸',
#  '아딸 떡볶이',
#  '오감자',
#  '화이트골드커피믹스',
#  '소불고기',
#  '김밥단무지',
#  '삼립',
#  '삼립빵',
#  '김밥어묵',
#  '구강청결제',
#  '맛살',
#  '당면',
#  '설레임',
#  '바나나킥',
#  '튀김우동',
#  '김밥햄',
#  '피망',
#  '쪽파',
#  '쫄면',
#  '쿨피스',
#  '참깨스틱',
#  '재래식된장',
#  '의성마늘햄',
#  '게토레이',
#  '손선풍기',
#  '리엔 흑모비책',
#  '흑모비책',
#  '염색약',
#  '미장센염색약',
#  '남성 반바지',
#  '롯데상품권',
#  '타프스크린',
#  '나이키 운동화',
#  '조이그라이슨',
#  '라그라치아',
#  '클러치백',
#  '폴스부띠끄가방',
#  '하객원피스',
#  '여성시계',
#  '필로소피 향수',
#  '질스튜어트가방',
#  '세인트스코트가방',
#  '파슬여성시계',
#  '파슬시계',
#  '스톤헨지시계',
#  '로이드메탈시계',
#  '여성향수',
#  '랑콤향수',
#  '로이드시계',
#  '폴바이스시계',
#  '마크제이콥스시계',
#  '제이에스티나시계',
#  '스톤헨지 시계',
#  '골든듀목걸이',
#  '스톤헨지목걸이',
#  '가네시 목걸이',
#  '티르리르',
#  '여성팔찌',
#  'A4',
#  '핸드워시',
#  '물비누',
#  '씻어나온쌀',
#  '컵라면박스',
#  '고당도수박',
#  '사과대추',
#  '쌀국수',
#  '빵',
#  '빠아앙',
#  '고래밥',
#  '양상추',
#  '쌀국수면',
#  '드레싱',
#  '김밥',
#  '또띠아',
#  '두두스토리',
#  '베네통키즈',
#  '가버',
#  '헤지스가방',
#  '커밍스텝',
#  '아동실내화',
#  '반에이크',
#  '페리미츠레깅스',
#  '베베드피노키즈',
#  '아디다스 키즈',
#  '아디다스',
#  '여아런닝',
#  '여아내의',
#  '페리미츠 레깅스',
#  '미쏘',
#  '플랫슈즈',
#  '윈',
#  '가을 원피스',
#  '수영가방',
#  '바바라슈즈',
#  '스퍼',
#  '여성나시',
#  '여성나시티',
#  '여성슬립온',
#  '린넨자켓여성',
#  '오버핏자켓',
#  '오버핏',
#  '정장바지',
#  '크록스',
#  '키즈크록스',
#  '포에버21',
#  '바캉스옷',
#  '바캉스커플룩',
#  '바캉스원피스',
#  '바캉스룩',
#  '토리버치 가방',
#  '시슬리',
#  '아디다스샌들',
#  '아디다스키즈',
#  '아동샌들',
#  '키즈샌들',
#  '린넨반팔자켓',
#  '공구우먼',
#  '캐미솔',
#  '린넨자켓',
#  '여름샌들',
#  '체크원피스',
#  '아쿠아슈즈아동',
#  '아쿠아슈즈',
#  '미쏘청바지',
#  '미쏘 티셔츠',
#  '청반바지여성',
#  '퍼프블라우스',
#  '미쏘리넨재킷',
#  '앤클라인가방',
#  '미나그램',
#  '린',
#  '립프로그',
#  '뉴발란스키즈',
#  '여아래쉬가드',
#  '노스페이스키즈래시가드',
#  '포카칩',
#  '케일',
#  '샐러드',
#  '쿠쉬쿠쉬',
#  '파스퇴르',
#  '포테토칩',
#  '휘슬러압력밥솥',
#  '냉동삼겹살',
#  '쌈무',
#  '쌈',
#  '청소포',
#  '고무장갑',
#  '비닐팩',
#  '위생팩',
#  '튜브',
#  '파인애플',
#  '새우',
#  '라이스페이퍼',
#  '월남쌈',
#  '껌',
#  '밤',
#  '오뚜기밥',
#  '갈비',
#  '갈비찜',
#  '식빵',
#  '메츄리알',
#  '반찬',
#  '햇반',
#  '바지락',
#  '누릉지',
#  '앤클라인',
#  '트리아나',
#  '700',
#  '필터',
#  ...]

# %%
act_kwd[0]
# Out:
# '라인에디션블라우스'

# %%
type(act_kwd[0])
# Out:
# str

# %%
len(act_kwd)
# Out:
# 101952

# %% [markdown]
#  * 시범 삼아 1개 추출

# %%
# Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행
driver=webdriver.Chrome('./chromedriver')

# %%
# 웹 페이지를 읽어오기
driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')

# find_element_by_id : id 속성으로 요소 하나 추출

a_element1=driver.find_element_by_id('headerQuery') # headerQuery : 검색어 입력 창
a_element1.click()                                  # 해당 요소를 클릭
a_element1.send_keys('로가디스')                     # 키를 입력


a_element2=driver.find_element_by_id("btn_headerSearch") # btn_headerSearch : 검색 버튼
a_element2.click()

a_element3=driver.find_element_by_class_name("content_category")

# %%
a_element3.text
# Out:
# '패션의류/언더웨어\n남성정장/셔츠 (1,133)\n남성캐주얼 (822)\n진/유니섹스 (52)\n명품/쥬얼리\n시계/보석/쥬얼리 (221)\n스포츠/레저\n스포츠패션/슈즈 (37)\n영플라자\n진/유니섹스 (26)\n롯데백화점\n진/유니섹스 (12)\n남성정장/셔츠 (3)\n남성캐주얼 (1)'

# %%
a_element4=a_element3.text.split('\n')

# %%
a_element4
# Out:
# ['패션의류/언더웨어',
#  '남성정장/셔츠 (1,133)',
#  '남성캐주얼 (822)',
#  '진/유니섹스 (52)',
#  '명품/쥬얼리',
#  '시계/보석/쥬얼리 (221)',
#  '스포츠/레저',
#  '스포츠패션/슈즈 (37)',
#  '영플라자',
#  '진/유니섹스 (26)',
#  '롯데백화점',
#  '진/유니섹스 (12)',
#  '남성정장/셔츠 (3)',
#  '남성캐주얼 (1)']

# %%
test=[]
for i in range(len(a_element4)):
    text = re.sub(r'\([^)]*\)', repl='', string=a_element4[i])
    text=text.rstrip()
    test.append(text)
a_element5=pd.Series(test,name=1)

# %%
a_element5
# Out:
# 0     패션의류/언더웨어
# 1       남성정장/셔츠
# 2         남성캐주얼
# 3        진/유니섹스
# 4        명품/쥬얼리
# 5     시계/보석/쥬얼리
# 6        스포츠/레저
# 7      스포츠패션/슈즈
# 8          영플라자
# 9        진/유니섹스
# 10        롯데백화점
# 11       진/유니섹스
# 12      남성정장/셔츠
# 13        남성캐주얼
# Name: 1, dtype: object

# %%
-------------------------------------------------------------------------------------------------------------------

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(1000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_1000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [56:17<00:00,  3.38s/it]

# %% [markdown]
#  * 1000 ~ 2000 번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(1000, 2000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_2000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [53:59<00:00,  3.24s/it]

# %% [markdown]
#  * 2000~3000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(2000, 3000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_3000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [58:36<00:00,  3.52s/it]

# %% [markdown]
#  * 3000 ~ 4000 번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(3000, 4000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_4000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [48:27<00:00,  2.91s/it]

# %% [markdown]
#  * 4000 ~ 5000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(4000, 5000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_5000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [50:23<00:00,  3.02s/it]

# %% [markdown]
#  * 5000 ~ 6000 번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(5000, 6000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_6000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [48:29<00:00,  2.91s/it]

# %% [markdown]
#  * 6000 ~ 7000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(6000, 7000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_7000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [47:21<00:00,  2.84s/it]

# %% [markdown]
#  * 7000 ~ 8000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(7000, 8000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_8000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [48:55<00:00,  2.94s/it]

# %% [markdown]
#  * 8000 ~ 9000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(8000, 9000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_9000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [51:48<00:00,  3.11s/it]

# %% [markdown]
#  * 9000 ~ 10000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(9000, 10000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_10000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [51:07<00:00,  3.07s/it]

# %%
 *

# %% [markdown]
#  * 26000~27000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(26000, 27000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_27000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [46:37<00:00,  2.80s/it]

# %% [markdown]
#  * 27000~28000번

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(27000, 28000)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_28000.csv", mode='w')
# Out:
# 100%|██████████| 1000/1000 [51:35<00:00,  3.10s/it]

# %%
act_kwd_cat=pd.Series(['시작'],name='start')
act_kwd_cat

driver=webdriver.Chrome('./chromedriver')  # Selenium이 사용할 브라우저 선택 및 크롬 드라이버 실행

# 1000개만 먼저
# 열 추가 방식
for i in tqdm(range(29000, 29900)):
    
#     driver.implicitly_wait(2)
    driver.get('http://www.lotteimall.com/main/viewMain.lotte?dpml_no=1&tlog=00100_1')
    a_element1=driver.find_element_by_id('headerQuery')
    a_element1.click()
    a_element1.send_keys(act_kwd_over3[i])
    a_element2=driver.find_element_by_id("btn_headerSearch")
    a_element2.click()
    try:
        if ('결과' in driver.find_element_by_class_name('center').text) == True:

            a_element3=driver.find_element_by_class_name("content_category")
            a_element4=a_element3.text.split('\n')
            test=[]
            for j in range(len(a_element4)):
                text = re.sub(r'\([^)]*\)', repl='', string=a_element4[j])
                text=text.rstrip()
                test.append(text)
            a_element5=pd.Series(test,name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element5],axis=1)
        else:
            a_element6=pd.Series(['검색이 되지 않는다'],name=i)
            act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)
    except:
        a_element6=pd.Series(['아예 검색 없음'],name=i)
        act_kwd_cat=pd.concat([act_kwd_cat,a_element6],axis=1)

# 파일 저장
act_kwd_cat.to_csv("sample_over3_29900.csv", mode='w')
# Out:
# 100%|██████████| 900/900 [45:46<00:00,  3.05s/it]

# %% [markdown]
#  * 롯데 홈쇼핑몰에서 추출한 카테고리 키워드 가져오기

# %%
cat_kwd_1 = pd.read_csv("./sample_over3_1000.csv")
cat_kwd_1 = cat_kwd_1.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_2 = pd.read_csv("./sample_over3_2000.csv")
cat_kwd_2 = cat_kwd_2.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_3 = pd.read_csv("./sample_over3_3000.csv")
cat_kwd_3 = cat_kwd_3.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_4 = pd.read_csv("./sample_over3_4000.csv")
cat_kwd_4 = cat_kwd_4.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_5 = pd.read_csv("./sample_over3_5000.csv")
cat_kwd_5 = cat_kwd_5.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_6 = pd.read_csv("./sample_over3_6000.csv")
cat_kwd_6 = cat_kwd_6.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_7 = pd.read_csv("./sample_over3_7000.csv")
cat_kwd_7 = cat_kwd_7.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_8 = pd.read_csv("./sample_over3_8000.csv")
cat_kwd_8 = cat_kwd_8.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_9 = pd.read_csv("./sample_over3_9000.csv")
cat_kwd_9 = cat_kwd_9.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_10 = pd.read_csv("./sample_over3_10000.csv")
cat_kwd_10 = cat_kwd_10.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_11 = pd.read_csv("./sample_over3_11000.csv")
cat_kwd_11 = cat_kwd_11.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_12 = pd.read_csv("./sample_over3_12000.csv")
cat_kwd_12 = cat_kwd_12.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_13 = pd.read_csv("./sample_over3_13000.csv")
cat_kwd_13 = cat_kwd_13.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_14 = pd.read_csv("./sample_over3_14000.csv")
cat_kwd_14 = cat_kwd_14.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_15 = pd.read_csv("./sample_over3_15000.csv")
cat_kwd_15 = cat_kwd_15.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_16 = pd.read_csv("./sample_over3_16000.csv")
cat_kwd_16 = cat_kwd_16.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_17 = pd.read_csv("./sample_over3_17000.csv")
cat_kwd_17 = cat_kwd_17.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_18 = pd.read_csv("./sample_over3_18000.csv")
cat_kwd_18 = cat_kwd_18.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_19 = pd.read_csv("./sample_over3_19000.csv")
cat_kwd_19 = cat_kwd_19.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_20 = pd.read_csv("./sample_over3_20000.csv")
cat_kwd_20 = cat_kwd_20.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_21 = pd.read_csv("./sample_over3_21000.csv")
cat_kwd_21 = cat_kwd_21.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_22 = pd.read_csv("./sample_over3_22000.csv")
cat_kwd_22 = cat_kwd_22.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_23 = pd.read_csv("./sample_over3_23000.csv")
cat_kwd_23 = cat_kwd_23.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_24 = pd.read_csv("./sample_over3_24000.csv")
cat_kwd_24 = cat_kwd_24.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_25 = pd.read_csv("./sample_over3_25000.csv")
cat_kwd_25 = cat_kwd_25.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_26 = pd.read_csv("./sample_over3_26000.csv")
cat_kwd_26 = cat_kwd_26.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_27 = pd.read_csv("./sample_over3_27000.csv")
cat_kwd_27 = cat_kwd_27.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_28 = pd.read_csv("./sample_over3_28000.csv")
cat_kwd_28 = cat_kwd_28.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_29 = pd.read_csv("./sample_over3_29000.csv")
cat_kwd_29 = cat_kwd_29.drop(['Unnamed: 0', 'start'], axis=1)
cat_kwd_299 = pd.read_csv("./sample_over3_29900.csv")
cat_kwd_299 = cat_kwd_299.drop(['Unnamed: 0', 'start'], axis=1)

# %%
cat_kwd_1.head(3)
# Out:
#            0          1          2          3          4         5          6  \
# 0     명품/쥬얼리     명품/쥬얼리     명품/쥬얼리     명품/쥬얼리  패션의류/언더웨어        식품  패션의류/언더웨어
# 1  수입명품/해외배송  수입명품/해외배송  수입명품/해외배송  수입명품/해외배송       언더웨어   즉석/가공식품    여성트랜드의류
# 2     스포츠/레저     스포츠/레저   주방/생활/건강  시계/보석/쥬얼리    여성브랜드의류  음료/커피/간식    여성브랜드의류
#
#          7           8           9  ...         990      991          992  \
# 0       식품  가구/침구/인테리어  검색이 되지 않는다  ...  가구/침구/인테리어       식품     주방/생활/건강
# 1  건강식품/홍삼    홈데코/인테리어         NaN  ...    홈데코/인테리어  즉석/가공식품           주방
# 2      NaN   침구/커튼/카페트         NaN  ...        전문매장     신선식품  문구/악기/도서/취미
#
#         993      994       995        996        997         998  \
# 0        식품       식품        식품  패션의류/언더웨어  패션의류/언더웨어  가구/침구/인테리어
# 1   즉석/가공식품     신선식품   즉석/가공식품    여성브랜드의류    여성브랜드의류    홈데코/인테리어
# 2  여행/렌탈/금융  즉석/가공식품  음료/커피/간식    여성트랜드의류    여성트랜드의류        침실가구
#
#                  999
# 0             가전/디지털
# 1  TV/냉장고/세탁기/계절가...
# 2         카메라/캠코더/드론
#
# [3 rows x 1000 columns]

# %%
cat_kwd_1_list = list(cat_kwd_1.iloc[0])
cat_kwd_2_list = list(cat_kwd_2.iloc[0])
cat_kwd_3_list = list(cat_kwd_3.iloc[0])
cat_kwd_4_list = list(cat_kwd_4.iloc[0])
cat_kwd_5_list = list(cat_kwd_5.iloc[0])
cat_kwd_6_list = list(cat_kwd_6.iloc[0])
cat_kwd_7_list = list(cat_kwd_7.iloc[0])
cat_kwd_8_list = list(cat_kwd_8.iloc[0])
cat_kwd_9_list = list(cat_kwd_9.iloc[0])
cat_kwd_10_list = list(cat_kwd_10.iloc[0])
cat_kwd_11_list = list(cat_kwd_11.iloc[0])
cat_kwd_12_list = list(cat_kwd_12.iloc[0])
cat_kwd_13_list = list(cat_kwd_13.iloc[0])
cat_kwd_14_list = list(cat_kwd_14.iloc[0])
cat_kwd_15_list = list(cat_kwd_15.iloc[0])
cat_kwd_16_list = list(cat_kwd_16.iloc[0])
cat_kwd_17_list = list(cat_kwd_17.iloc[0])
cat_kwd_18_list = list(cat_kwd_18.iloc[0])
cat_kwd_19_list = list(cat_kwd_19.iloc[0])
cat_kwd_20_list = list(cat_kwd_20.iloc[0])
cat_kwd_21_list = list(cat_kwd_21.iloc[0])
cat_kwd_22_list = list(cat_kwd_22.iloc[0])
cat_kwd_23_list = list(cat_kwd_23.iloc[0])
cat_kwd_24_list = list(cat_kwd_24.iloc[0])
cat_kwd_25_list = list(cat_kwd_25.iloc[0])
cat_kwd_26_list = list(cat_kwd_26.iloc[0])
cat_kwd_27_list = list(cat_kwd_27.iloc[0])
cat_kwd_28_list = list(cat_kwd_28.iloc[0])
cat_kwd_29_list = list(cat_kwd_29.iloc[0])
cat_kwd_299_list = list(cat_kwd_299.iloc[0])

cat_kwd_list = cat_kwd_1_list + cat_kwd_2_list + cat_kwd_3_list + cat_kwd_4_list + cat_kwd_5_list \
               + cat_kwd_6_list + cat_kwd_7_list + cat_kwd_8_list + cat_kwd_9_list + cat_kwd_10_list \
               + cat_kwd_11_list + cat_kwd_12_list + cat_kwd_13_list + cat_kwd_14_list + cat_kwd_15_list \
               + cat_kwd_16_list + cat_kwd_17_list + cat_kwd_18_list + cat_kwd_19_list + cat_kwd_20_list \
               + cat_kwd_21_list + cat_kwd_22_list + cat_kwd_23_list + cat_kwd_24_list + cat_kwd_25_list \
               + cat_kwd_26_list + cat_kwd_27_list + cat_kwd_28_list + cat_kwd_29_list + cat_kwd_299_list

# %%
len(cat_kwd_list)
# Out:
# 29900

# %%
cat_kwd_list
# Out:
# ['명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '가구/침구/인테리어',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  'U아동관',
#  '식품',
#  '반려동물',
#  '식품',
#  '명품/쥬얼리',
#  '식품',
#  '식품',
#  '화장품/미용',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '식품',
#  '가구/침구/인테리어',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '식품',
#  '주방/생활/건강',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '주방/생활/건강',
#  '가전/디지털',
#  '가전/디지털',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '가전/디지털',
#  '식품',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '식품',
#  '스포츠/레저',
#  '화장품/미용',
#  '검색이 되지 않는다',
#  'U아동관',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '주방/생활/건강',
#  '여행/렌탈/금융',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '가전/디지털',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '롯데백화점',
#  'U아동관',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  'U아동관',
#  '롯데백화점',
#  '가구/침구/인테리어',
#  '검색이 되지 않는다',
#  '식품',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '전문매장',
#  '가구/침구/인테리어',
#  '롯데백화점',
#  '화장품/미용',
#  '명품/쥬얼리',
#  '화장품/미용',
#  '식품',
#  '가구/침구/인테리어',
#  '여행/렌탈/금융',
#  '가구/침구/인테리어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '롯데백화점',
#  '롯데백화점',
#  '롯데백화점',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '식품',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '식품',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '명품/쥬얼리',
#  '전문매장',
#  '식품',
#  '가전/디지털',
#  '식품',
#  '스포츠/레저',
#  '롯데백화점',
#  'U아동관',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '검색이 되지 않는다',
#  '화장품/미용',
#  '검색이 되지 않는다',
#  '식품',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '주방/생활/건강',
#  '식품',
#  '가구/침구/인테리어',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '식품',
#  '반려동물',
#  '식품',
#  '가구/침구/인테리어',
#  '스포츠/레저',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '가전/디지털',
#  'U아동관',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '스포츠/레저',
#  '식품',
#  '화장품/미용',
#  '롯데백화점',
#  '검색이 되지 않는다',
#  '화장품/미용',
#  '롯데백화점',
#  '롯데백화점',
#  '롯데백화점',
#  '롯데백화점',
#  '화장품/미용',
#  '화장품/미용',
#  'U아동관',
#  '명품/쥬얼리',
#  '검색이 되지 않는다',
#  'U아동관',
#  '가전/디지털',
#  '롯데백화점',
#  '잡화/슈즈',
#  '식품',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '전문매장',
#  '식품',
#  '롯데백화점',
#  '스포츠/레저',
#  '가전/디지털',
#  '패션의류/언더웨어',
#  '식품',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '주방/생활/건강',
#  '명품/쥬얼리',
#  '가구/침구/인테리어',
#  '스포츠/레저',
#  '명품/쥬얼리',
#  '식품',
#  '명품/쥬얼리',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '명품/쥬얼리',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '반려동물',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '스포츠/레저',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '전문매장',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '전문매장',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '전문매장',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '반려동물',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '식품',
#  '롯데백화점',
#  '가전/디지털',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '롯데백화점',
#  '가전/디지털',
#  '가전/디지털',
#  '가전/디지털',
#  '가전/디지털',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '롯데백화점',
#  '롯데백화점',
#  '롯데백화점',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '전문매장',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '잡화/슈즈',
#  '화장품/미용',
#  '롯데백화점',
#  '롯데백화점',
#  '화장품/미용',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '전문매장',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '식품',
#  '화장품/미용',
#  '가전/디지털',
#  '스포츠/레저',
#  '가전/디지털',
#  '가전/디지털',
#  '식품',
#  '가구/침구/인테리어',
#  '주방/생활/건강',
#  '스포츠/레저',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '검색이 되지 않는다',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '화장품/미용',
#  '화장품/미용',
#  '롯데백화점',
#  '롯데백화점',
#  '롯데백화점',
#  '반려동물',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '롯데백화점',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '전문매장',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '식품',
#  'U아동관',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '여행/렌탈/금융',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '식품',
#  '롯데백화점',
#  '화장품/미용',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '여행/렌탈/금융',
#  '식품',
#  '반려동물',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '스포츠/레저',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '가구/침구/인테리어',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '식품',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '검색이 되지 않는다',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '전문매장',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '롯데백화점',
#  '반려동물',
#  '반려동물',
#  '롯데백화점',
#  '주방/생활/건강',
#  '식품',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '롯데백화점',
#  '식품',
#  '식품',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '스포츠/레저',
#  '식품',
#  '식품',
#  '식품',
#  '반려동물',
#  '롯데백화점',
#  '주방/생활/건강',
#  '명품/쥬얼리',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '검색이 되지 않는다',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '전문매장',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '가전/디지털',
#  '식품',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '가전/디지털',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '여행/렌탈/금융',
#  '주방/생활/건강',
#  '가전/디지털',
#  'U아동관',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '화장품/미용',
#  '명품/쥬얼리',
#  '롯데백화점',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '식품',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '롯데백화점',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '여행/렌탈/금융',
#  '명품/쥬얼리',
#  'U아동관',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '검색이 되지 않는다',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '잡화/슈즈',
#  '화장품/미용',
#  '잡화/슈즈',
#  'U아동관',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  '잡화/슈즈',
#  '화장품/미용',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '검색이 되지 않는다',
#  '잡화/슈즈',
#  '여행/렌탈/금융',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '검색이 되지 않는다',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '식품',
#  '식품',
#  '반려동물',
#  'U아동관',
#  '검색이 되지 않는다',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '롯데백화점',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '전문매장',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '스포츠/레저',
#  '가전/디지털',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '식품',
#  '가구/침구/인테리어',
#  'U아동관',
#  '식품',
#  '롯데백화점',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '여행/렌탈/금융',
#  '가구/침구/인테리어',
#  '식품',
#  '스포츠/레저',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '화장품/미용',
#  '화장품/미용',
#  '잡화/슈즈',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '스포츠/레저',
#  '스포츠/레저',
#  '전문매장',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '롯데백화점',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '반려동물',
#  '식품',
#  '식품',
#  '잡화/슈즈',
#  '반려동물',
#  '여행/렌탈/금융',
#  '식품',
#  '식품',
#  '식품',
#  'e카탈로그',
#  '식품',
#  '롯데백화점',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '롯데백화점',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '화장품/미용',
#  '화장품/미용',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '검색이 되지 않는다',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  '가전/디지털',
#  '롯데백화점',
#  '스포츠/레저',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '반려동물',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '가구/침구/인테리어',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '명품/쥬얼리',
#  '화장품/미용',
#  '식품',
#  '검색이 되지 않는다',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '가구/침구/인테리어',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '롯데백화점',
#  '가구/침구/인테리어',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '롯데백화점',
#  '화장품/미용',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  'U아동관',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '반려동물',
#  '식품',
#  '전문매장',
#  '식품',
#  '식품',
#  '식품',
#  'U아동관',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '가전/디지털',
#  '화장품/미용',
#  '화장품/미용',
#  '화장품/미용',
#  'e카탈로그',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '화장품/미용',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '화장품/미용',
#  '화장품/미용',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '주방/생활/건강',
#  '전문매장',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '식품',
#  '검색이 되지 않는다',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '가구/침구/인테리어',
#  '식품',
#  'U아동관',
#  '롯데백화점',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '스포츠/레저',
#  'U아동관',
#  '패션의류/언더웨어',
#  'U아동관',
#  '롯데백화점',
#  '스포츠/레저',
#  '스포츠/레저',
#  '롯데백화점',
#  '롯데백화점',
#  'U아동관',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '잡화/슈즈',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '전문매장',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '명품/쥬얼리',
#  '패션의류/언더웨어',
#  '스포츠/레저',
#  '스포츠/레저',
#  'U아동관',
#  'U아동관',
#  '패션의류/언더웨어',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '패션의류/언더웨어',
#  'U아동관',
#  '스포츠/레저',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '잡화/슈즈',
#  '검색이 되지 않는다',
#  '패션의류/언더웨어',
#  'U아동관',
#  '스포츠/레저',
#  '스포츠/레저',
#  '스포츠/레저',
#  '식품',
#  '잡화/슈즈',
#  '주방/생활/건강',
#  '식품',
#  '롯데백화점',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '주방/생활/건강',
#  '스포츠/레저',
#  '가구/침구/인테리어',
#  '식품',
#  '식품',
#  '식품',
#  '반려동물',
#  'U아동관',
#  '식품',
#  '식품',
#  '식품',
#  '가구/침구/인테리어',
#  '식품',
#  '주방/생활/건강',
#  '식품',
#  '식품',
#  '식품',
#  '패션의류/언더웨어',
#  '패션의류/언더웨어',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  ...]

# %% [markdown]
# * 중복 제거한 카테고리 키워드 갯수

# %%
cat_kwd_set = set(cat_kwd_list)

# %%
len(cat_kwd_set)
# Out:
# 20

# %%
cat_kwd_set
# Out:
# {'TV쇼핑',
#  'U아동관',
#  'e카탈로그',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  '검색이 되지 않는다',
#  '롯데백화점',
#  '롯데아울렛',
#  '명품/쥬얼리',
#  '반려동물',
#  '스포츠/레저',
#  '식품',
#  '아예 검색 없음',
#  '여행/렌탈/금융',
#  '영플라자',
#  '잡화/슈즈',
#  '전문매장',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '화장품/미용'}

# %% [markdown]
#  * 3번 이상 검색된 키워드와 그 키워드 검색에 따른 롯데홈쇼핑 카테고리를 연결한 table 데이터 선언
#      * sech_kwd_over_3 : 3번 이상 검색된 키워드
#      * sech_kwd_cat : 3번 이상 검색된 키워드를 롯데홈쇼핑몰에서 검색하여 나온 카테고리 키워드

# %%
sech_kwd_cat_dict = {'sech_kwd_over_3':act_kwd_over3, 'sech_kwd_cat':cat_kwd_list}
sech_kwd_cat_table = pd.DataFrame(sech_kwd_cat_dict)

# %%
sech_kwd_cat_table
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 0                펜디가방       명품/쥬얼리
# 1              페레가모가방       명품/쥬얼리
# 2                루이비통       명품/쥬얼리
# 3                  구찌       명품/쥬얼리
# 4                속옷세트    패션의류/언더웨어
# ...               ...          ...
# 29895          쉬폰밴딩팬츠    패션의류/언더웨어
# 29896     anf 유기농 양고기         반려동물
# 29897          드립 여과지     주방/생활/건강
# 29898           옥수수수프           식품
# 29899            레쓰비ㅣ   검색이 되지 않는다
#
# [29900 rows x 2 columns]

# %% [markdown]
#  * Table 파일 저장

# %%
sech_kwd_cat_table.to_csv("sech_kwd_cat.csv", mode='w')

# %% [markdown]
#  * 카테고리 키워드 관련 EDA

# %%
sech_kwd_cat_table['sech_kwd_cat'].value_counts()
# Out:
# 식품            6113
# 패션의류/언더웨어     4496
# 검색이 되지 않는다    3917
# 스포츠/레저        3106
# 주방/생활/건강      1904
# 가구/침구/인테리어    1753
# U아동관          1514
# 잡화/슈즈         1429
# 명품/쥬얼리        1366
# 롯데백화점         1262
# 화장품/미용        1055
# 가전/디지털         848
# 전문매장           495
# 반려동물           317
# 여행/렌탈/금융       215
# e카탈로그           61
# 아예 검색 없음        35
# 롯데아울렛            7
# 영플라자             6
# TV쇼핑             1
# Name: sech_kwd_cat, dtype: int64

# %% [markdown]
#  * 카테고리 키워드 별 상품 살펴보기
#      * 키워드만 보고 상품 유추가 안되는 항목 위주로 확인

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '롯데백화점'].head(50)
# Out:
#      sech_kwd_over_3 sech_kwd_cat
# 93           립 마에스트로        롯데백화점
# 100            빈 원피스        롯데백화점
# 108           프레쉬 립밤        롯데백화점
# 128             빈 여아        롯데백화점
# 129                빈        롯데백화점
# 130         타미힐피거칠드런        롯데백화점
# 148       베네피트 아이브로우        롯데백화점
# 177          록시땅 버베나        롯데백화점
# 180        에스티로더 립스틱        롯데백화점
# 181         에스티로더 크림        롯데백화점
# 182            에스티로더        롯데백화점
# 183          슈에무라립스틱        롯데백화점
# 191       에스티로더 마스카라        롯데백화점
# 198           록시땅 샴푸        롯데백화점
# 290         밍크뮤 바디슈트        롯데백화점
# 296              러브캣        롯데백화점
# 304              빌리프        롯데백화점
# 305             베네피트        롯데백화점
# 306           눈썹마스카라        롯데백화점
# 330          입생로랑 cc        롯데백화점
# 331        입생로랑 cc크림        롯데백화점
# 379              록시땅        롯데백화점
# 380        아르마니 립마그넷        롯데백화점
# 381             섹스어필        롯데백화점
# 391       블루독베이비 상하복        롯데백화점
# 422           미장센에센스        롯데백화점
# 496            스파게티면        롯데백화점
# 499              클리오        롯데백화점
# 506              설화수        롯데백화점
# 518   에스티로더더블웨어파운데이션        롯데백화점
# 590            디올 향수        롯데백화점
# 610           입생로랑쿠션        롯데백화점
# 672            신발주머니        롯데백화점
# 692           뉴트라라이프        롯데백화점
# 731             롯데닷컴        롯데백화점
# 747               청귤        롯데백화점
# 754             무염버터        롯데백화점
# 785             프리메라        롯데백화점
# 813             슈에무라        롯데백화점
# 819            바비브라운        롯데백화점
# 906            베네통키즈        롯데백화점
# 913          베베드피노키즈        롯데백화점
# 916             여아런닝        롯데백화점
# 917             여아내의        롯데백화점
# 970             파스퇴르        롯데백화점
# 1102          시세이도쿠션        롯데백화점
# 1107          블랙야크키즈        롯데백화점
# 1144             만전김        롯데백화점
# 1166           키엘에센스        롯데백화점
# 1181        설화수탄력에센셜        롯데백화점

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '롯데아울렛']
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 8780         퀘스타 슬라이드        롯데아울렛
# 8782           f37031        롯데아울렛
# 13991               랲        롯데아울렛
# 14597          ce2033        롯데아울렛
# 18228       에이치커넥트원피스        롯데아울렛
# 18232      에이치커넥트 원피스        롯데아울렛
# 21376      MAEC01-102        롯데아울렛

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '전문매장'].head(50)
# Out:
#      sech_kwd_over_3 sech_kwd_cat
# 106            선풍기커버         전문매장
# 143               차퍼         전문매장
# 196            유칼립투스         전문매장
# 249              뉴슈가         전문매장
# 262               데코         전문매장
# 269          다이슨드라이기         전문매장
# 323          슈콤마보니샌들         전문매장
# 339              요플레         전문매장
# 396          종량제봉투10         전문매장
# 489               소금         전문매장
# 534              무드등         전문매장
# 676             솔로몬샵         전문매장
# 728             제이핑크         전문매장
# 843              설레임         전문매장
# 891              물비누         전문매장
# 937           바캉스커플룩         전문매장
# 1182           에어컨커버         전문매장
# 1183            텐바이텐         전문매장
# 1249             전구지         전문매장
# 1317          샌드위치식빵         전문매장
# 1357             칼림바         전문매장
# 1378            마요네즈         전문매장
# 1379             베이컨         전문매장
# 1410             메르베         전문매장
# 1733             보냉백         전문매장
# 1744          프릴주방세제         전문매장
# 1910             종이컵         전문매장
# 1919           일회용접시         전문매장
# 2147           카림라시드         전문매장
# 2317             건프라         전문매장
# 2331        텐바이텐 3.0         전문매장
# 2385         쓰레기봉투10         전문매장
# 2618             앞치마         전문매장
# 2705            애플펜슬         전문매장
# 2764           바나나걸이         전문매장
# 2775         샤오미 선풍기         전문매장
# 3037           빨래바구니         전문매장
# 3071             고사리         전문매장
# 3270            카푸치노         전문매장
# 3285            두루마리         전문매장
# 3366           토스트식빵         전문매장
# 3410             메이플         전문매장
# 3426         쓰리엠 물걸레         전문매장
# 3486             빵빠레         전문매장
# 3627         eme커트러리         전문매장
# 3700            치킨타올         전문매장
# 3729            종이접시         전문매장
# 3730         일회용종이접시         전문매장
# 3755          토스트 식빵         전문매장
# 3837              민두         전문매장

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == 'e카탈로그'].head(50)
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 745          비비고 열무김치        e카탈로그
# 859            미장센염색약        e카탈로그
# 2000            롯데홈쇼핑        e카탈로그
# 2165           짜파게티5입        e카탈로그
# 2740           안성탕면5입        e카탈로그
# 3161              슈멜츠        e카탈로그
# 4033        농심 짜파게티5입        e카탈로그
# 5166            씨제이고메        e카탈로그
# 5186         씨제이진한칼국수        e카탈로그
# 5459         고메함박스테이크        e카탈로그
# 7150           고메 돈까스        e카탈로그
# 7694         요구르트비피더스        e카탈로그
# 7759           시크릿에이지        e카탈로그
# 8567            얼큰칼국수        e카탈로그
# 8869           비비고 열무        e카탈로그
# 8970          비비고 삼계탕        e카탈로그
# 8977            버섯칼국수        e카탈로그
# 9327    크로커다일 민소매 티셔츠        e카탈로그
# 10668            고메함박        e카탈로그
# 10669          고메 미트볼        e카탈로그
# 11355          여자명품샌들        e카탈로그
# 11578           햄버거패티        e카탈로그
# 11608         비비고 반계탕        e카탈로그
# 11845           스틱썬크림        e카탈로그
# 12340           cj 국수        e카탈로그
# 12348        비비고교자칼국수        e카탈로그
# 12816         씨제이제일제당        e카탈로그
# 13175           황성주생식        e카탈로그
# 13196           명품운동화        e카탈로그
# 13719           교자칼국수        e카탈로그
# 13971          비비고삼계탕        e카탈로그
# 14033           고메 함박        e카탈로그
# 14541        비피더스요쿠르트        e카탈로그
# 14579        고메 치즈돈까스        e카탈로그
# 15099         여성기초화장품        e카탈로그
# 15431         잠실롯데백화점        e카탈로그
# 15824             애즈모        e카탈로그
# 15933           고메돈까스        e카탈로그
# 16073              게리        e카탈로그
# 17167       에스까다 마스카라        e카탈로그
# 17441       비피더스 요구르트        e카탈로그
# 18413  엘리자베스아덴 그린티 로션        e카탈로그
# 18720           줌바댄스복        e카탈로그
# 18898      안다르에어쿨링8.2        e카탈로그
# 19179            자라신발        e카탈로그
# 19799        샌들 여성 명품        e카탈로그
# 20632            브리오신        e카탈로그
# 21131         명품 스니커즈        e카탈로그
# 22602           진한칼국수        e카탈로그
# 23205             라라쎄        e카탈로그

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '아예 검색 없음']
# Out:
#                                          sech_kwd_over_3 sech_kwd_cat
# 1648                                           결과 내 재 검색     아예 검색 없음
# 1848                                            14345001     아예 검색 없음
# 3451                                           베개솜 50×70     아예 검색 없음
# 4199                                       하남쭈꾸미 500g×3팩     아예 검색 없음
# 7083                                              생수2l×6     아예 검색 없음
# 8611                                                   "     아예 검색 없음
# 11049                                               포모라인     아예 검색 없음
# 11993                                             鞂€10kg     아예 검색 없음
# 12601                                         7219235004     아예 검색 없음
# 13564                                         7259220002     아예 검색 없음
# 13572                                         7128150002     아예 검색 없음
# 13937                        하남쭈꾸미 500g×3팩1팩당 2 3인분 무료배송     아예 검색 없음
# 15414                                           샤넬가브리엘향수     아예 검색 없음
# 16457  K2[케이투]S/S 가격인하 남성 ASCENT ICE 7부 팬츠 KMM18317 Z...     아예 검색 없음
# 17308                                           45309638     아예 검색 없음
# 17309                                           18190013     아예 검색 없음
# 22352                                             샤넬 레베쥬     아예 검색 없음
# 22654                                            삠뽀요 원피스     아예 검색 없음
# 23317                                  ë¯¸êµ­ì‚°laê°ˆë¹„     아예 검색 없음
# 23649                                           10048506     아예 검색 없음
# 24802                                         7259337001     아예 검색 없음
# 25561                                      생수 2L×12 무료배송     아예 검색 없음
# 25562                                       생수 2L×6 무료배송     아예 검색 없음
# 25649                                            WMF압력밥솥     아예 검색 없음
# 26325                                             엠브리올리스     아예 검색 없음
# 26529                                          클라란스에센셜크림     아예 검색 없음
# 26548                                               투고쿠션     아예 검색 없음
# 27155                                           비비드매트 90     아예 검색 없음
# 27601                                              론드주얼리     아예 검색 없음
# 27833                                         7259260022     아예 검색 없음
# 28291                                        쿠션커버 40 ×40     아예 검색 없음
# 28981                                         1292778479     아예 검색 없음
# 29500                                             퓨리나 덴탈     아예 검색 없음
# 29704                                           더예한복 조바위     아예 검색 없음
# 29758                                         9109111999     아예 검색 없음

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '검색이 되지 않는다']
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 9                enqn   검색이 되지 않는다
# 17            비비고포기김치   검색이 되지 않는다
# 31              빠질라카노   검색이 되지 않는다
# 63               생만두피   검색이 되지 않는다
# 64              냉동만두피   검색이 되지 않는다
# ...               ...          ...
# 29880       아닉구딸쁘띠드쉐리   검색이 되지 않는다
# 29886       아닉구딸 쁘띠 드   검색이 되지 않는다
# 29887         무스텔라 향수   검색이 되지 않는다
# 29890         여자반바지정장   검색이 되지 않는다
# 29899            레쓰비ㅣ   검색이 되지 않는다
#
# [3917 rows x 2 columns]

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == '영플라자']
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 12064        빈폴레이디스점퍼         영플라자
# 12065        빈폴레이디스자켓         영플라자
# 21284        티파니 겨울점퍼         영플라자
# 24246          흄캐쥬얼자켓         영플라자
# 25459            영캐주얼         영플라자
# 26125       빈폴레이디스 자켓         영플라자

# %%
sech_kwd_cat_table[sech_kwd_cat_table['sech_kwd_cat'] == 'TV쇼핑']
# Out:
#       sech_kwd_over_3 sech_kwd_cat
# 25210        나무하나 멜로우         TV쇼핑

# %%
# 4. 상품 대중소 분류 정보
raw_data4_Item_Class = pd.read_csv('./data/data4_Item_Class.csv')

# %%
raw_data4_Item_Class.head(3)
# Out:
#    pd_c             clac_nm1  \
# 0     1  Automotive Products
# 1     2  Automotive Products
# 2     3  Automotive Products
#
#                                            clac_nm2  \
# 0  Automotive Replacement Repair / Maintanance Kits
# 1  Automotive Replacement Repair / Maintanance Kits
# 2  Automotive Replacement Repair / Maintanance Kits
#
#                      clac_nm3
# 0  Automobile Oil / Additives
# 1                  Car Lights
# 2                   Car Paint

# %%
raw_data4_Item_Class['clac_nm1'].value_counts()
# Out:
# Fashion Accessories                          100
# Meats                                         80
# Sea Foods                                     76
# Vegetables                                    70
# Kids' Clothing                                67
# Stationary / Office Supplies                  61
# Fruits                                        56
# Underwear / Socks and Hosiery / Homewear      53
# Sport Fashion                                 52
# Spices / Seasonings                           49
# Cosmetics / Beauty Care                       48
# Personal Care                                 38
# Snack Foods                                   36
# Cooked Foods                                  35
# Tableware / Cooking Utensils                  35
# Gardening / Pets                              35
# Home / Kitchen Appliances                     33
# Chilled Foods                                 32
# Kitchenware                                   30
# Cleaning / Laundry / Bathroom Accessories     30
# Bedding / Handicraft                          30
# Automotive Products                           29
# Health Foods                                  29
# Toy                                           29
# Detergents / Hygiene Goods                    28
# Ball Game / Field Sports                      28
# Dried Sea Foods                               27
# Outdoor / Leisure Activities                  26
# Substitute Foods                              26
# Birth Supplies / Baby Products                26
# Furniture                                     26
# Women's Clothing                              25
# Beverages                                     23
# Liquors / Alcoholic Beverages                 21
# Health Care                                   21
# Frozen Foods                                  20
# Men's Clothing                                20
# Home Decor / Lighting                         18
# Coffee / Tea                                  18
# Tenants / Restaurants                         17
# Seasonal Sports                               17
# Grains                                        15
# Canned / Jarred Foods                         15
# Video / Audio System Electronics              14
# Computers                                     13
# Tools / Safety Supplies                       13
# Health / Fitness Training                     12
# Books / Records / Instruments                  9
# Dairy Products                                 9
# Heating / Cooling Electronics                  9
# Living / Rental Services                       6
# Cell Phones / Accessories                      6
# Refrigerators and Washing Machines             5
# Gift Certificates / Cards                      5
# Baby Foods                                     4
# Travel / Leisure Services                      3
# Finance / Insurance Service                    3
# Tobacco                                        3
# Others (Non-Products)                          2
# Other Products                                 1
# Name: clac_nm1, dtype: int64

# %%
len(raw_data4_Item_Class['clac_nm1'].value_counts())
# Out:
# 60

# %%
raw_data4_Item_Class['clac_nm2'].value_counts()
# Out:
# Fish                               19
# Kitchen Appliances                 17
# Domestic Fruits                    16
# Leaf Vegetables                    16
# Imported Fruits                    16
#                                    ..
# Ready to Drinks                     1
# Toy Vehicles                        1
# Bag Sets                            1
# Other Furniture                     1
# Fixed-price General Merchandise     1
# Name: clac_nm2, Length: 332, dtype: int64

# %%
raw_data4_Item_Class['clac_nm3'].value_counts()
# Out:
# Lunch Boxes                           2
# Peppers                               2
# Salads                                2
# Processed Chicken Eggs                1
# LED Lamps                             1
#                                      ..
# Magnet / Pins                         1
# Adult's Diapers                       1
# Yoga Mats / Exercise Mats             1
# Other Kids' Socks and Hosiery Sets    1
# Half-Dried Fish                       1
# Name: clac_nm3, Length: 1662, dtype: int64

# %%
cat_kwd_set
# Out:
# {'TV쇼핑',
#  'U아동관',
#  'e카탈로그',
#  '가구/침구/인테리어',
#  '가전/디지털',
#  '검색이 되지 않는다',
#  '롯데백화점',
#  '롯데아울렛',
#  '명품/쥬얼리',
#  '반려동물',
#  '스포츠/레저',
#  '식품',
#  '아예 검색 없음',
#  '여행/렌탈/금융',
#  '영플라자',
#  '잡화/슈즈',
#  '전문매장',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '화장품/미용'}

# %%
cat_kwd_unique_list= list(cat_kwd_set)
cat_kwd_unique_list
# Out:
# ['명품/쥬얼리',
#  '가구/침구/인테리어',
#  'U아동관',
#  'e카탈로그',
#  '주방/생활/건강',
#  '잡화/슈즈',
#  '여행/렌탈/금융',
#  '스포츠/레저',
#  '검색이 되지 않는다',
#  '전문매장',
#  '화장품/미용',
#  '반려동물',
#  '아예 검색 없음',
#  '롯데백화점',
#  '가전/디지털',
#  '식품',
#  '롯데아울렛',
#  '패션의류/언더웨어',
#  'TV쇼핑',
#  '영플라자']

# %%
# 여러 상품 분류가 섞여있는 카테고리 키워드
remove_set = {'검색이 되지 않는다', '아예 검색 없음', '롯데백화점', '롯데아울렛', 'e카탈로그', 'TV쇼핑', '전문매장'}

# %%
cat_kwd_list_unique = list(cat_kwd_set - remove_set)
cat_kwd_list_unique
# Out:
# ['가구/침구/인테리어',
#  '스포츠/레저',
#  '가전/디지털',
#  'U아동관',
#  '명품/쥬얼리',
#  '식품',
#  '주방/생활/건강',
#  '패션의류/언더웨어',
#  '화장품/미용',
#  '잡화/슈즈',
#  '영플라자',
#  '반려동물',
#  '여행/렌탈/금융']
